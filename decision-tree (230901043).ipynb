# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

df=pd.read_excel("decisiontree.xlsx")
print("Original data:\n",df)

d={"UK":0,"USA":1,"India":2}
df["Nationality"]=df['Nationality'].map(d)
d={"Yes":1,"No":2}
df["Go"]=df["Go"].map(d)
features=["Age","Experience","Rank","Nationality"]
x=df[features]
y=df["Go"]
dtree=DecisionTreeClassifier()
dtree=dtree.fit(x,y)
tree.plot_tree(dtree,feature_names=features)
plt.show()
# Out:
# Original data:
#      Name  Age  Experience  Rank Nationality   Go
# 0  Alice   25           2     3         USA  Yes
# 1    Bob   30           5     2          UK   No
# 2  Clara   28           3     4          UK  Yes
# 3  David   35          10     1         USA  Yes
# 4    Eva   22           1     5       India   No
# 5  Frank   40          15     1          UK   No
# 6  Grace   27           4     4         USA  Yes
# 7  Henry   33           8     2       India  Yes
# 8   Isla   29           6     3          UK   No
# 9   Jack   31           7     2       India  Yes
